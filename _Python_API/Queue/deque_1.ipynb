# %% [markdown]
# ## Queue Using collections.deque:
#
# - A double-ended queue that supports adding and removing elements from both ends efficiently. Suitable for most queue implementations.

# %% [markdown]
# ### This is the most common and efficient way to implement a queue.

# %%
from collections import deque

# Create a queue
queue = deque()

# Enqueue (add elements)
queue.append('A')
queue.append('B')
queue.append('C')
print(queue)  # Output: deque(['A', 'B', 'C'])

# Dequeue (remove elements)
front = queue.popleft()
print(front)  # Output: 'A'
print(queue)  # Output: deque(['B', 'C'])

# Check if the queue is empty
print(len(queue) == 0)  # Output: False

# %% [markdown]
# ## pop()

# %%
queue = deque()
queue.append('A')
queue.append('B')
queue.append('C')
print(queue)

queue.pop()
queue
# Out:
# deque(['A', 'B', 'C'])
# deque(['A', 'B'])

# %% [markdown]
# ## popLeft()

# %%
queue = deque()
queue.append('A')
queue.append('B')
queue.append('C')

queue.popleft()
queue
# Out:
# deque(['B', 'C'])
